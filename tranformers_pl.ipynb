# %%
import os
cwd = os.getcwd()
cwd
# Out:
# 'c:\\PS\\ERA_V1\\era_v1_session_15'

# %%
# %pip install pytorch-lightning
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytorch-lightning in c:\users\pankaja\appdata\roaming\python\python310\site-packages (1.9.5)
# Requirement already satisfied: numpy>=1.17.2 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from pytorch-lightning) (1.25.1)
# Requirement already satisfied: torch>=1.10.0 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from pytorch-lightning) (2.0.1)
# Requirement already satisfied: tqdm>=4.57.0 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from pytorch-lightning) (4.65.0)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from pytorch-lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from pytorch-lightning) (2023.6.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from pytorch-lightning) (0.11.4)
# Requirement already satisfied: packaging>=17.1 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from pytorch-lightning) (23.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from pytorch-lightning) (4.7.1)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from pytorch-lightning) (0.9.0)
# Requirement already satisfied: requests in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (3.8.5)
# Requirement already satisfied: filelock in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from torch>=1.10.0->pytorch-lightning) (3.12.2)
# Requirement already satisfied: sympy in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from torch>=1.10.0->pytorch-lightning) (1.11.1)
# Requirement already satisfied: networkx in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from torch>=1.10.0->pytorch-lightning) (3.1)
# Requirement already satisfied: jinja2 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from torch>=1.10.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: colorama in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from tqdm>=4.57.0->pytorch-lightning) (0.4.6)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from jinja2->torch>=1.10.0->pytorch-lightning) (2.1.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from sympy->torch>=1.10.0->pytorch-lightning) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\pankaja\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\pankaja\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\pankaja\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\pankaja\appdata\roaming\python\python310\site-packages)

# %%
# %pip install tokenizers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tokenizers
#   Downloading tokenizers-0.13.3-cp310-cp310-win_amd64.whl (3.5 MB)
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      -- ------------------------------------- 0.2/3.5 MB 7.3 MB/s eta 0:00:01
#      ---------------------- ----------------- 2.0/3.5 MB 25.3 MB/s eta 0:00:01
#      ---------------------------------------- 3.5/3.5 MB 27.7 MB/s eta 0:00:00
# Installing collected packages: tokenizers
# Successfully installed tokenizers-0.13.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\pankaja\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\pankaja\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\pankaja\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\pankaja\appdata\roaming\python\python310\site-packages)

# %%
# %pip install datasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting datasets
#   Obtaining dependency information for datasets from https://files.pythonhosted.org/packages/66/f8/38298237d18d4b6a8ee5dfe390e97bed5adb8e01ec6f9680c0ddf3066728/datasets-2.14.4-py3-none-any.whl.metadata
#   Downloading datasets-2.14.4-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from datasets) (1.25.1)
# Collecting pyarrow>=8.0.0 (from datasets)
#   Obtaining dependency information for pyarrow>=8.0.0 from https://files.pythonhosted.org/packages/f1/04/0c0589aea14748b310489361f732ee813aa9cda0736933d7af8d0225654c/pyarrow-13.0.0-cp310-cp310-win_amd64.whl.metadata
#   Downloading pyarrow-13.0.0-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Obtaining dependency information for dill<0.3.8,>=0.3.0 from https://files.pythonhosted.org/packages/f5/3a/74a29b11cf2cdfcd6ba89c0cecd70b37cd1ba7b77978ce611eb7a146a832/dill-0.3.7-py3-none-any.whl.metadata
#   Downloading dill-0.3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: pandas in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from datasets) (4.65.0)
# Collecting xxhash (from datasets)
#   Obtaining dependency information for xxhash from https://files.pythonhosted.org/packages/4b/7e/ab636507e53955770a2622b550265f8ee9e68feb2374ba151570a5d82e64/xxhash-3.3.0-cp310-cp310-win_amd64.whl.metadata
#   Downloading xxhash-3.3.0-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Obtaining dependency information for multiprocess from https://files.pythonhosted.org/packages/35/a8/36d8d7b3e46b377800d8dec47891cdf05842d1a2366909ae4a0c89fbc5e6/multiprocess-0.70.15-py310-none-any.whl.metadata
#   Downloading multiprocess-0.70.15-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from datasets) (3.8.5)
# Collecting huggingface-hub<1.0.0,>=0.14.0 (from datasets)
#   Obtaining dependency information for huggingface-hub<1.0.0,>=0.14.0 from https://files.pythonhosted.org/packages/7f/c4/adcbe9a696c135578cabcbdd7331332daad4d49b7c43688bc2d36b3a47d2/huggingface_hub-0.16.4-py3-none-any.whl.metadata
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from aiohttp->datasets) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from requests>=2.19.0->datasets) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from requests>=2.19.0->datasets) (2023.5.7)
# Requirement already satisfied: colorama in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-2.14.4-py3-none-any.whl (519 kB)
#    ---------------------------------------- 0.0/519.3 kB ? eta -:--:--
#    -------------------- ------------------ 276.5/519.3 kB 16.6 MB/s eta 0:00:01
#    --------------------------------------- 519.3/519.3 kB 10.8 MB/s eta 0:00:00
# Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#    ---------------------------------------- 0.0/115.3 kB ? eta -:--:--
#    ---------------------------------------- 115.3/115.3 kB 6.6 MB/s eta 0:00:00
# Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#    ---------------------------------------- 0.0/268.8 kB ? eta -:--:--
#    ---------------------------------------- 268.8/268.8 kB ? eta 0:00:00
# Downloading pyarrow-13.0.0-cp310-cp310-win_amd64.whl (24.3 MB)
#    ---------------------------------------- 0.0/24.3 MB ? eta -:--:--
#    ---- ----------------------------------- 2.5/24.3 MB 53.9 MB/s eta 0:00:01
#    --------- ------------------------------ 6.0/24.3 MB 64.6 MB/s eta 0:00:01
#    -------------- ------------------------- 8.9/24.3 MB 63.7 MB/s eta 0:00:01
#    --------------------- ------------------ 12.8/24.3 MB 72.6 MB/s eta 0:00:01
#    --------------------------- ------------ 16.5/24.3 MB 72.6 MB/s eta 0:00:01
#    --------------------------------- ------ 20.3/24.3 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  24.0/24.3 MB 72.6 MB/s eta 0:00:01
#    ---------------------------------------  24.3/24.3 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------- 24.3/24.3 MB 59.4 MB/s eta 0:00:00
# Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#    ---------------------------------------- 0.0/134.8 kB ? eta -:--:--
#    ---------------------------------------- 134.8/134.8 kB ? eta 0:00:00
# Downloading xxhash-3.3.0-cp310-cp310-win_amd64.whl (29 kB)
# Installing collected packages: xxhash, pyarrow, dill, multiprocess, huggingface-hub, datasets
# Successfully installed datasets-2.14.4 dill-0.3.7 huggingface-hub-0.16.4 multiprocess-0.70.15 pyarrow-13.0.0 xxhash-3.3.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\pankaja\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\pankaja\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\pankaja\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\pankaja\appdata\roaming\python\python310\site-packages)

# %%
# %pip install -U torchtext
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torchtext
#   Using cached torchtext-0.15.2-cp310-cp310-win_amd64.whl (1.9 MB)
# Requirement already satisfied: tqdm in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from torchtext) (4.65.0)
# Requirement already satisfied: requests in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from torchtext) (2.31.0)
# Requirement already satisfied: torch==2.0.1 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from torchtext) (2.0.1)
# Requirement already satisfied: numpy in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from torchtext) (1.25.1)
# Collecting torchdata==0.6.1 (from torchtext)
#   Using cached torchdata-0.6.1-cp310-cp310-win_amd64.whl (1.3 MB)
# Requirement already satisfied: filelock in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from torch==2.0.1->torchtext) (3.12.2)
# Requirement already satisfied: typing-extensions in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from torch==2.0.1->torchtext) (4.7.1)
# Requirement already satisfied: sympy in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from torch==2.0.1->torchtext) (1.11.1)
# Requirement already satisfied: networkx in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from torch==2.0.1->torchtext) (3.1)
# Requirement already satisfied: jinja2 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from torch==2.0.1->torchtext) (3.1.2)
# Requirement already satisfied: urllib3>=1.25 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from torchdata==0.6.1->torchtext) (1.26.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from requests->torchtext) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from requests->torchtext) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from requests->torchtext) (2023.5.7)
# Requirement already satisfied: colorama in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from tqdm->torchtext) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from jinja2->torch==2.0.1->torchtext) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\pankaja\appdata\roaming\python\python310\site-packages (from sympy->torch==2.0.1->torchtext) (1.2.1)
# Installing collected packages: torchdata, torchtext
# Successfully installed torchdata-0.6.1 torchtext-0.15.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\pankaja\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\pankaja\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\pankaja\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\pankaja\appdata\roaming\python\python310\site-packages)

# %%
import torchtext.datasets as datasets

# %%
## Standard libraries
import os
import numpy as np
import random
import math
import json
from functools import partial

## Imports for plotting
import matplotlib.pyplot as plt
plt.set_cmap('cividis')
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg', 'pdf') # For export
from matplotlib.colors import to_rgb
import matplotlib
matplotlib.rcParams['lines.linewidth'] = 2.0
import seaborn as sns
sns.reset_orig()

## tqdm for loading bars
from tqdm.notebook import tqdm

## PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
import torch.optim as optim

## Torchvision
import torchvision
from torchvision.datasets import CIFAR100
from torchvision import transforms

# PyTorch Lightning
try:
    import pytorch_lightning as pl
except ModuleNotFoundError: # Google Colab does not have PyTorch Lightning installed by default. Hence, we do it here if necessary
    # %pip install --quiet pytorch-lightning>=1.4
    import pytorch_lightning as pl
from pytorch_lightning.callbacks import LearningRateMonitor, ModelCheckpoint

# Path to the folder where the datasets are/should be downloaded (e.g. CIFAR10)
DATASET_PATH = "../data"
# Path to the folder where the pretrained models are saved
CHECKPOINT_PATH = "../saved_models"

# Setting the seed
pl.seed_everything(42)

# Ensure that all operations are deterministic on GPU (if used) for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
print("Device:", device)
# Out:
# C:\Users\Pankaja\AppData\Local\Temp\ipykernel_29232\625682561.py:14: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg', 'pdf') # For export
# Global seed set to 42
# Device: cpu

# %%
# class TransformerPredictor(pl.LightningModule):

#     def __init__(self, input_dim, model_dim, num_classes, num_heads, num_layers, lr, warmup, max_iters, dropout=0.0, input_dropout=0.0):
#         """
#         Inputs:
#             input_dim - Hidden dimensionality of the input
#             model_dim - Hidden dimensionality to use inside the Transformer
#             num_classes - Number of classes to predict per sequence element
#             num_heads - Number of heads to use in the Multi-Head Attention blocks
#             num_layers - Number of encoder blocks to use.
#             lr - Learning rate in the optimizer
#             warmup - Number of warmup steps. Usually between 50 and 500
#             max_iters - Number of maximum iterations the model is trained for. This is needed for the CosineWarmup scheduler
#             dropout - Dropout to apply inside the model
#             input_dropout - Dropout to apply on the input features
#         """
#         super().__init__()
#         self.save_hyperparameters()
#         self._create_model()

#     def _create_model(self):
#         # Input dim -> Model dim
#         self.input_net = nn.Sequential(
#             nn.Dropout(self.hparams.input_dropout),
#             nn.Linear(self.hparams.input_dim, self.hparams.model_dim)
#         )
#         # Positional encoding for sequences
#         self.positional_encoding = PositionalEncoding(d_model=self.hparams.model_dim)
#         # Transformer
#         self.transformer = TransformerEncoder(num_layers=self.hparams.num_layers,
#                                               input_dim=self.hparams.model_dim,
#                                               dim_feedforward=2*self.hparams.model_dim,
#                                               num_heads=self.hparams.num_heads,
#                                               dropout=self.hparams.dropout)
#         # Output classifier per sequence lement
#         self.output_net = nn.Sequential(
#             nn.Linear(self.hparams.model_dim, self.hparams.model_dim),
#             nn.LayerNorm(self.hparams.model_dim),
#             nn.ReLU(inplace=True),
#             nn.Dropout(self.hparams.dropout),
#             nn.Linear(self.hparams.model_dim, self.hparams.num_classes)
#         )

#     def forward(self, x, mask=None, add_positional_encoding=True):
#         """
#         Inputs:
#             x - Input features of shape [Batch, SeqLen, input_dim]
#             mask - Mask to apply on the attention outputs (optional)
#             add_positional_encoding - If True, we add the positional encoding to the input.
#                                       Might not be desired for some tasks.
#         """
#         x = self.input_net(x)
#         if add_positional_encoding:
#             x = self.positional_encoding(x)
#         x = self.transformer(x, mask=mask)
#         x = self.output_net(x)
#         return x

#     @torch.no_grad()
#     def get_attention_maps(self, x, mask=None, add_positional_encoding=True):
#         """
#         Function for extracting the attention matrices of the whole Transformer for a single batch.
#         Input arguments same as the forward pass.
#         """
#         x = self.input_net(x)
#         if add_positional_encoding:
#             x = self.positional_encoding(x)
#         attention_maps = self.transformer.get_attention_maps(x, mask=mask)
#         return attention_maps

#     def configure_optimizers(self):
#         optimizer = optim.Adam(self.parameters(), lr=self.hparams.lr)

#         # Apply lr scheduler per step
#         lr_scheduler = CosineWarmupScheduler(optimizer,
#                                              warmup=self.hparams.warmup,
#                                              max_iters=self.hparams.max_iters)
#         return [optimizer], [{'scheduler': lr_scheduler, 'interval': 'step'}]

#     def training_step(self, batch, batch_idx):
#         raise NotImplementedError

#     def validation_step(self, batch, batch_idx):
#         raise NotImplementedError

#     def test_step(self, batch, batch_idx):
#         raise NotImplementedError

# %%
from model import *

# %%
class TransformerPredictor(pl.LightningModule):
    def __init__(
        self,
        input_dim,
        model_dim,
        num_classes,
        num_heads,
        num_layers,
        lr,
        warmup,
        max_iters,
        dropout=0.0,
        input_dropout=0.0,
    ):
        """
        Args:
            input_dim: Hidden dimensionality of the input
            model_dim: Hidden dimensionality to use inside the Transformer
            num_classes: Number of classes to predict per sequence element
            num_heads: Number of heads to use in the Multi-Head Attention blocks
            num_layers: Number of encoder blocks to use.
            lr: Learning rate in the optimizer
            warmup: Number of warmup steps. Usually between 50 and 500
            max_iters: Number of maximum iterations the model is trained for. This is needed for the CosineWarmup scheduler
            dropout: Dropout to apply inside the model
            input_dropout: Dropout to apply on the input features
        """
        super().__init__()
        self.save_hyperparameters()
        self._create_model()

    def _create_model(self):
        # Input dim -> Model dim
        self.input_net = nn.Sequential(
            nn.Dropout(self.hparams.input_dropout), nn.Linear(self.hparams.input_dim, self.hparams.model_dim)
        )
        # Positional encoding for sequences
        self.positional_encoding = PositionalEncoding(d_model=self.hparams.model_dim)
        # Transformer
        self.transformer = TransformerEncoder(
            num_layers=self.hparams.num_layers,
            input_dim=self.hparams.model_dim,
            dim_feedforward=2 * self.hparams.model_dim,
            num_heads=self.hparams.num_heads,
            dropout=self.hparams.dropout,
        )
        # Output classifier per sequence lement
        self.output_net = nn.Sequential(
            nn.Linear(self.hparams.model_dim, self.hparams.model_dim),
            nn.LayerNorm(self.hparams.model_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(self.hparams.dropout),
            nn.Linear(self.hparams.model_dim, self.hparams.num_classes),
        )

    def forward(self, x, mask=None, add_positional_encoding=True):
        """
        Args:
            x: Input features of shape [Batch, SeqLen, input_dim]
            mask: Mask to apply on the attention outputs (optional)
            add_positional_encoding: If True, we add the positional encoding to the input.
                                      Might not be desired for some tasks.
        """
        x = self.input_net(x)
        if add_positional_encoding:
            x = self.positional_encoding(x)
        x = self.transformer(x, mask=mask)
        x = self.output_net(x)
        return x

    @torch.no_grad()
    def get_attention_maps(self, x, mask=None, add_positional_encoding=True):
        """Function for extracting the attention matrices of the whole Transformer for a single batch.

        Input arguments same as the forward pass.
        """
        x = self.input_net(x)
        if add_positional_encoding:
            x = self.positional_encoding(x)
        attention_maps = self.transformer.get_attention_maps(x, mask=mask)
        return attention_maps

    def configure_optimizers(self):
        optimizer = optim.Adam(self.parameters(), lr=self.hparams.lr)

        # We don't return the lr scheduler because we need to apply it per iteration, not per epoch
        self.lr_scheduler = CosineWarmupScheduler(
            optimizer, warmup=self.hparams.warmup, max_iters=self.hparams.max_iters
        )
        return optimizer

    def optimizer_step(self, *args, **kwargs):
        super().optimizer_step(*args, **kwargs)
        self.lr_scheduler.step()  # Step per iteration

    def training_step(self, batch, batch_idx):
        raise NotImplementedError

    def validation_step(self, batch, batch_idx):
        raise NotImplementedError

    def test_step(self, batch, batch_idx):
        raise NotImplementedError
